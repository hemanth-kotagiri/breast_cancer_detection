# %%
import pandas as pd
import numpy as np

data_df = pd.read_csv("Data/data.csv")

# %%
data_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
FEATURES = ['radius_mean', 'texture_mean', 'perimeter_mean',
            'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
            'radius_worst', 'texture_worst',
            'perimeter_worst', 'area_worst', 'smoothness_worst',
            'compactness_worst', 'concavity_worst', 'concave points_worst',
            'symmetry_worst', 'fractal_dimension_worst']

# %%
COLUMNS = data_df.columns

# %%
y = data_df["diagnosis"].apply(lambda x: 1 if x == 'M' else 0)

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data_df[FEATURES]

# %%
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  radius_worst  texture_worst  \
# 0           0.27760          0.3001         25.38          17.33
# 1           0.07864          0.0869         24.99          23.41
# 2           0.15990          0.1974         23.57          25.53
# 3           0.28390          0.2414         14.91          26.50
# 4           0.13280          0.1980         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  radius_worst  \
# count       569.000000        569.000000      569.000000    569.000000
# mean          0.096360          0.104341        0.088799     16.269190
# std           0.014064          0.052813        0.079720      4.833242
# min           0.052630          0.019380        0.000000      7.930000
# 25%           0.086370          0.064920        0.029560     13.010000
# 50%           0.095870          0.092630        0.061540     14.970000
# 75%           0.105300          0.130400        0.130700     18.790000
# max           0.163400          0.345400        0.426800     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)

# %%
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.9298245614035088

# %%
from sklearn.model_selection import learning_curve

# %%
train_sizes, train_scores, test_scores, fit_times, _ = learning_curve(
        model,
        df,
        y,
        cv=10,
        n_jobs=-1,
        train_sizes=np.linspace(0.1, 1.0, 20),
        return_times=True,
    )

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
import matplotlib.pyplot as plt
plt.plot(train_sizes, train_scores_mean, label="Training")
plt.plot(train_sizes, test_scores_mean, label="CV")
plt.xlabel("Size")
plt.ylabel("Accuracy")
plt.title("Learning Curves")
plt.legend(loc='bottom right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_375884/1709438475.py in <module>
#       5 plt.ylabel("Accuracy")
#       6 plt.title("Learning Curves")
# ----> 7 plt.legend(loc='bottom right')
#       8 plt.show()
#
# /media/data/Workspace/AI~ML~DP/breast_cancer_detection/venv/lib/python3.9/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    2653 @_copy_docstring_and_deprecators(Axes.legend)
#    2654 def legend(*args, **kwargs):
# -> 2655     return gca().legend(*args, **kwargs)
#    2656
#    2657
#
# /media/data/Workspace/AI~ML~DP/breast_cancer_detection/venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
#     304             raise TypeError('legend only accepts two non-keyword arguments')
# --> 305         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306         self.legend_._remove_method = self._remove_legend
#     307         return self.legend_
#
# /media/data/Workspace/AI~ML~DP/breast_cancer_detection/venv/lib/python3.9/site-packages/matplotlib/legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncol, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map, title_fontproperties)
#     453                 loc = 'upper right'
#     454         if isinstance(loc, str):
# --> 455             loc = _api.check_getitem(self.codes, loc=loc)
#     456         if not self.isaxes and loc == 0:
#     457             raise ValueError(
#
# /media/data/Workspace/AI~ML~DP/breast_cancer_detection/venv/lib/python3.9/site-packages/matplotlib/_api/__init__.py in check_getitem(_mapping, **kwargs)
#     186         return mapping[v]
#     187     except KeyError:
# --> 188         raise ValueError(
#     189             "{!r} is not a valid value for {}; supported values are {}"
#     190             .format(v, k, ', '.join(map(repr, mapping)))) from None
#
# ValueError: 'bottom right' is not a valid value for loc; supported values are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'

# %%
train_sizes
# Out:
# array([ 55,  82, 108, 134, 161, 187, 214, 240, 266, 293, 319, 345, 372,
#        398, 425, 451, 477, 504, 530, 557])

# %%
train_scores_mean
# Out:
# array([0.98254545, 0.97487805, 0.96444444, 0.97059701, 0.96832298,
#        0.9686631 , 0.96364486, 0.96666667, 0.96639098, 0.96716724,
#        0.96683386, 0.96869565, 0.96763441, 0.96768844, 0.96517647,
#        0.96580931, 0.9602935 , 0.96301587, 0.96350943, 0.96186715])
